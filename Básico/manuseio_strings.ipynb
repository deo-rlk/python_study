# %%
frase_teste = "He is called 'Johnny'"
print(frase_teste[14:20])
# Out:
# Johnny

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
for x in 'banana':
    print(x, end='')
# Out:
# banana

# %%
texto_teste = 'The best things in life are free!'
print('free' in texto_teste)

if 'free' in texto_teste:
    print("Yes 'free' is present")
# Out:
# True
# Yes 'free' is present

# %%
a = "Hello, World"

print(f"""
Exemplos abaixo

Com inicio e fim: {a[2:5]}

Apenas com argumento final(inicial fica como 0): {a[:5]}

Apenas com argumento inicial(inicial fica como 0): {a[5:]}

""")
# Out:
# Exemplos abaixo
#
# Com inicio e fim: llo
#
# Apenas com argumento final(inicial fica como 0): Hello
#
# Apenas com argumento inicial(inicial fica como 0): , World

# %%
a = "Hello World"

a = a.upper()

print(a)
# Out:
# HELLO WORLD

# %%
a = 'Hello World'

a = a.replace('H', 'J')

print(a)
# Out:
# Jello World

# %%
a = "xxxxoi xx"
print(a.strip("x"))
# Out:
# oi
