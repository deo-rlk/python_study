# %% [markdown]
# #### Erro ao concatenar string com número

# %%
age = 36
txt = f"My name is Jhon, I am {36}"
print(txt)
# Out:
# My name is Jhon, I am 36

# %% [markdown]
# #### f-string: inserindo valores dentro de chaves

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %% [markdown]
# #### Usando aspas escapadas dentro de strings

# %%
texto = "Ele disse : \"Python é fácil\" "
print(texto)
# Out:
# Ele disse : "Python é fácil"
